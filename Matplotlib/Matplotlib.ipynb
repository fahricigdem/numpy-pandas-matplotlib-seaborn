# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
x=["1.ABD","2.ÇİN","3.JAPONYA","4.ALMANYA","5.İNGİLTERE","6.FRANSA"]
y=[20410,14090,5170,4210,2940,2930]
z=[63039,9957,40649,51158,44162,44915]

# %%
plt.plot(x,y,"r")
plt.xlabel("ÜLKELER")
plt.ylabel("MİLLİ GELİR")
plt.title("ÜLKELERE GÖRE MİLLİ GELİR")
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r--")
plt.title("ÜLKELERE GÖRE MİLLİ GELİR")

plt.subplot(1,2,2)
plt.plot(x,z,"y*-")

plt.tight_layout()

# %%
f=plt.figure()
axes=f.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,y)
axes.set_xlabel("ÜLKELER")
axes.set_ylabel("MİLLİ GELİR")
axes.set_title("ÜLKELERE GÖRE MİLLİ GELİR")
# Out:
# Text(0.5, 1.0, 'ÜLKELERE GÖRE MİLLİ GELİR')

# %%
f=plt.figure()
axes1=f.add_axes([0.1,0.1,0.9,0.9])
axes2=f.add_axes([0.5,0.5,0.4,0.4])
axes1.plot(x,y,"y")
axes2.plot(x,z,"r")

# %%
fig,axes=plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y,"b")
axes[0].set_title("MİLLİ GELİR")

axes[1].plot(x,z,"y")
axes[1].set_title("KİŞİ BAŞINA")

plt.tight_layout()

# %%
f=plt.figure()
axes=f.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,y,color="red",linewidth=1,linestyle="-",marker="o",markersize=20,markerfacecolor="yellow",markeredgewidth=4,markeredgecolor="blue",alpha=0.9)
axes.set_xlabel("ÜLKELER")
axes.set_ylabel("MİLLİ GELİR")
axes.set_title("ÜLKELERE GÖRE MİLLİ GELİR")
# Out:
# Text(0.5,1,'ÜLKELERE GÖRE MİLLİ GELİR')

# %%
f=plt.figure()
axes=f.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,y,color="red",linewidth=1,linestyle="-")
axes.set_xlabel("ÜLKELER")
axes.set_ylabel("MİLLİ GELİR")
axes.set_title("ÜLKELERE GÖRE MİLLİ GELİR")

axes.set_xlim([2,6])
axes.set_ylim([2000,7500])
# Out:
# (2000, 7500)

# %%
f=plt.figure(figsize=(10,6))
axes=f.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_xlabel("ÜLKELER")
axes.set_ylabel("MİLLİ GELİR")
axes.set_title("ÜLKELERE GÖRE MİLLİ GELİR")
# Out:
# Text(0.5,1,'ÜLKELERE GÖRE MİLLİ GELİR')

# %%
fig,axes=plt.subplots(nrows=1, ncols=2,figsize=(13,5))

axes[0].plot(x,y,"b")
axes[0].set_title("MİLLİ GELİR")

axes[1].plot(x,z,"y")
axes[1].set_title("KİŞİ BAŞINA")

plt.tight_layout()

# %%
fig.savefig("resim.png")

# %%
fig=plt.figure(figsize=(10,5))

ax=fig.add_axes([0,0,1,1])

ax.plot(x,y,"r",label="milli gelir")
ax.plot(x,z,"y",label="kişi başına")

ax.legend(loc=5)

# %% [markdown]
# # scatter

# %%
plt.scatter(x,y)

# %%
c=pd.read_csv("dünya.csv")
c.head()
# Out:
#         Ülke     Gelir     Nüfus  Kişi Başına           KITA
# 0        ABD  20410000   323,766        63039  Kuzey Amerika
# 1        Çin  14090000  1415,045         9957           Asya
# 2    Japonya   5170000   127,185        40649           Asya
# 3    Almanya   4210000    82,293        51158         Avrupa
# 4  İngiltere   2940000    66,573        44162         Avrupa

# %%
plt.scatter(c["Ülke"],c["Kişi Başına"])

# %% [markdown]
# # histogram

# %%
plt.hist(c["Kişi Başına"],bins=10)
# Out:
# (array([5., 2., 1., 2., 3., 3., 2., 1., 0., 1.]),
#  array([ 2104. , 10556.2, 19008.4, 27460.6, 35912.8, 44365. , 52817.2,
#         61269.4, 69721.6, 78173.8, 86626. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # step

# %%
plt.step(x,y)

# %% [markdown]
# # piecharts

# %%
labels = 'TÜRKİYE', 'ABD', 'ÇİN', 'ALMANYA'
sizes = [15, 35, 35, 15]
explode = (0, 0, 0.2, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.1214342579351884,
#  1.2996355610726353,
#  -1.1953380084490308,
#  1.1045399051642395)

# %%
plt.pie([12,32,15,23])
# Out:
# ([<matplotlib.patches.Wedge at 0x23b0bf59048>,
# ...
#  [Text(0.9857821210166344, 0.4880918047703174, ''),
#   Text(-0.5979242312061724, 0.92330201653441, ''),
#   Text(-0.7627758395568124, -0.7925736676097687, ''),
#   Text(0.6998666051660467, -0.8486381649285831, '')])

# %%
plt.pie([12,32,15,23],labels=['a','b','c','d'],explode = (0, 0, 0.3, 0), autopct='%1.3f%%',shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x23b0bef2648>,
# ...
#  [Text(-0.48809180477031705, 0.9857821210166346, 'a'),
#   Text(-0.92330201653441, -0.5979242312061723, 'b'),
#   Text(1.0087301224124328, -0.9708056139813978, 'c'),
#   Text(0.8486381649285832, 0.6998666051660466, 'd')],
#  [Text(-0.266231893511082, 0.5376993387363461, '14.634%'),
#   Text(-0.5036192817460418, -0.3261404897488212, '39.024%'),
#   Text(0.6484693644079924, -0.6240893232737557, '18.293%'),
#   Text(0.4628935445064999, 0.38174542099966174, '28.049%')])
