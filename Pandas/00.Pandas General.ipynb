# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('wcplayers.csv')

# %%
df
# Out:
#           Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0    Argentina   3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 1    Argentina  22   MF      PAVON Cristian  21.01.1996       PAVÓN
# 2    Argentina  15   MF      LANZINI Manuel  15.02.1993     LANZINI
# 3    Argentina  18   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 4    Argentina  10   FW        MESSI Lionel  24.06.1987       MESSI
# ..         ...  ..  ...                 ...         ...         ...
# 731    Uruguay  15   MF       VECINO Matias  24.08.1991      VECINO
# 732    Uruguay  23   GK        SILVA Martin  25.03.1983    M. SILVA
# 733    Uruguay   9   FW         SUAREZ Luis  24.01.1987      SUAREZ
# 734    Uruguay  18   FW   GOMEZ Maximiliano  14.08.1996    M. GOMEZ
# 735    Uruguay  19   DF    COATES Sebastian  07.10.1990      COATES
#
#                          Club  Height  Weight
# 0              AFC Ajax (NED)     169      65
# 1       CA Boca Juniors (ARG)     169      65
# ...

# %%
df['Age Order']=df['Birth Date'].rank(ascending=False).astype(int)
df.sort_values(by='Age Order').head()
# Out:
#           Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 221    England  19   FW     RASHFORD Marcus  31.10.1997    RASHFORD
# 614     Serbia  12   GK    RAJKOVIC Predrag  31.10.1995    RAJKOVIĆ
# 443     Panama   9   FW      TORRES Gabriel  31.10.1988   G. TORRES
# 0    Argentina   3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 512   Portugal  21   DF              CEDRIC  31.08.1991      CÉDRIC
#
#                            Club  Height  Weight  Age Order
# 221  Manchester United FC (ENG)     180      78          1
# 614   Maccabi Tel-Aviv FC (ISR)     191      85          2
# 443         CD Huachipato (CHI)     180      77          3
# 0                AFC Ajax (NED)     169      65          4
# 512        Southampton FC (ENG)     172      67          5

# %%
df[df['FIFA Popular Name'].isin(['TORRES Gabriel'])]
# Out:
#        Team  # Pos. FIFA Popular Name  Birth Date Shirt Name  \
# 443  Panama  9   FW    TORRES Gabriel  31.10.1988  G. TORRES
#
#                     Club  Height  Weight  Age Order
# 443  CD Huachipato (CHI)     180      77          3

# %%
df[df['FIFA Popular Name'].str.contains('Gabriel')]
# Out:
#           Team  # Pos. FIFA Popular Name  Birth Date Shirt Name  \
# 17   Argentina  2   DF   MERCADO Gabriel  18.03.1987    MERCADO
# 443     Panama  9   FW    TORRES Gabriel  31.10.1988  G. TORRES
# 450     Panama  6   MF     GOMEZ Gabriel  29.05.1984      GOMEZ
#
#                            Club  Height  Weight  Age Order
# 17             Sevilla FC (ESP)     181      81        317
# 443         CD Huachipato (CHI)     180      77          3
# 450  Atlético Bucaramanga (COL)     183      82         44

# %%
df["FIFA Popular Name"].str.split(" ").str.get(1).str.title().value_counts()
# Out:
# Jose         7
# Carlos       6
# Luis         6
# Cristian     5
# Thomas       5
#             ..
# Seunghyun    1
# Franco       1
# Hiroki       1
# Giancarlo    1
# Michy        1
# Name: FIFA Popular Name, Length: 531, dtype: int64

# %%
df[["ilk isim","soyisim"]]=df["FIFA Popular Name"].str.split(" ",expand=True,n=1)
df
# Out:
#           Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0    ARGENTINA   3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 1    ARGENTINA  22   MF      PAVON Cristian  21.01.1996       PAVÓN
# 2    ARGENTINA  15   MF      LANZINI Manuel  15.02.1993     LANZINI
# 3    ARGENTINA  18   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 4    ARGENTINA  10   FW        MESSI Lionel  24.06.1987       MESSI
# ..         ...  ..  ...                 ...         ...         ...
# 731    Uruguay  15   MF       VECINO Matias  24.08.1991      VECINO
# 732    Uruguay  23   GK        SILVA Martin  25.03.1983    M. SILVA
# 733    Uruguay   9   FW         SUAREZ Luis  24.01.1987      SUAREZ
# 734    Uruguay  18   FW   GOMEZ Maximiliano  14.08.1996    M. GOMEZ
# 735    Uruguay  19   DF    COATES Sebastian  07.10.1990      COATES
#
#                          Club  Height  Weight  Age Order    ilk isim  \
# 0              AFC Ajax (NED)     169      65          4  TAGLIAFICO
# ...

# %%
df.head()
# Out:
#         Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  ARGENTINA   3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 1  ARGENTINA  22   MF      PAVON Cristian  21.01.1996       PAVÓN
# 2  ARGENTINA  15   MF      LANZINI Manuel  15.02.1993     LANZINI
# 3  ARGENTINA  18   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 4  ARGENTINA  10   FW        MESSI Lionel  24.06.1987       MESSI
#
#                        Club  Height  Weight  Age Order    ilk isim   soyisim
# 0            AFC Ajax (NED)     169      65          4  TAGLIAFICO   Nicolas
# 1     CA Boca Juniors (ARG)     169      65        250       PAVON  Cristian
# 2  West Ham United FC (ENG)     167      66        399     LANZINI    Manuel
# 3          SL Benfica (POR)     167      69        441      SALVIO   Eduardo
# 4        FC Barcelona (ESP)     170      72        177       MESSI    Lionel

# %%
df['Team'].unique(), df['Team'].nunique()
# Out:
# (array(['Argentina', 'Australia', 'Belgium', 'Brazil', 'Colombia',
#         'Costa Rica', 'Croatia', 'Denmark', 'Egypt', 'England', 'France',
#         'Germany', 'Iceland', 'IR Iran', 'Japan', 'Korea Republic',
#         'Mexico', 'Morocco', 'Nigeria', 'Panama', 'Peru', 'Poland',
#         'Portugal', 'Russia', 'Saudi Arabia', 'Senegal', 'Serbia', 'Spain',
#         'Sweden', 'Switzerland', 'Tunisia', 'Uruguay'], dtype=object), 32)

# %%
df.loc[df['Team']=='Argentina','Team']='ARGENTINA'
df.head()
# Out:
#         Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  ARGENTINA   3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 1  ARGENTINA  22   MF      PAVON Cristian  21.01.1996       PAVÓN
# 2  ARGENTINA  15   MF      LANZINI Manuel  15.02.1993     LANZINI
# 3  ARGENTINA  18   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 4  ARGENTINA  10   FW        MESSI Lionel  24.06.1987       MESSI
#
#                        Club  Height  Weight  Age Order
# 0            AFC Ajax (NED)     169      65          4
# 1     CA Boca Juniors (ARG)     169      65        250
# 2  West Ham United FC (ENG)     167      66        399
# 3          SL Benfica (POR)     167      69        441
# 4        FC Barcelona (ESP)     170      72        177

# %% [markdown]
# # str functions: split etc...

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %%
df["FIFA Popular Name"].str.split(" ").str.get(0).str.title().value_counts()
# Out:
# Rodriguez    6
# Kim          5
# Mohamed      5
# Ben          5
# Lee          3
#             ..
# Smith        1
# Subasic      1
# Calderon     1
# Harit        1
# Vargas       1
# Name: FIFA Popular Name, Length: 669, dtype: int64

# %% [markdown]
# # csv dosyaları

# %%
d =pd.read_csv("https://data.cdc.gov/api/views/bi63-dtpu/rows.csv")
d.shape
# Out:
# (10868, 6)

# %%
d.head()
# Out:
#    Year                                     113 Cause Name  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State  Deaths  Age-adjusted Death Rate
# 0  Unintentional injuries  United States  169936                     49.4
# 1  Unintentional injuries        Alabama    2703                     53.8
# 2  Unintentional injuries         Alaska     436                     63.7
# 3  Unintentional injuries        Arizona    4184                     56.2
# 4  Unintentional injuries       Arkansas    1625                     51.8

# %%
d['State'].tolist()
# Out:
# ['United States',
#  'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'United States',
#  'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
# ...

# %%
state=d["State"].to_frame()
state
# Out:
#                State
# 0      United States
# 1            Alabama
# 2             Alaska
# 3            Arizona
# 4           Arkansas
# ...              ...
# 10863       Virginia
# 10864     Washington
# 10865  West Virginia
# 10866      Wisconsin
# 10867        Wyoming
#
# [10868 rows x 1 columns]

# %%
state.to_csv("state.csv",index=False)

# %%
pd.read_csv("state.csv")
# Out:
#                State
# 0      United States
# 1            Alabama
# 2             Alaska
# 3            Arizona
# 4           Arkansas
# ...              ...
# 10863       Virginia
# 10864     Washington
# 10865  West Virginia
# 10866      Wisconsin
# 10867        Wyoming
#
# [10868 rows x 1 columns]

# %% [markdown]
# # excel dosyaları

# %%
c = pd.read_excel("excel.xlsx",sheet_name=["2006","2010"])

# %%
c["2010"]
# Out:
#           Futbolcu  Gol
# 0      David Villa    5
# 1  Wesley Sneijder    5
# 2     Diego Forlan    5
# 3    Thomas Müller    5
# 4   Miroslav Klose    4
# 5    Robert Vittek    4
# 6        G.Higuain    4
# 7     Asamoah Gyan    3
# 8   Landon Donovan    3
# 9      Luis Suares    3

# %%
dört=pd.read_csv("2014 wc.csv")

# %%
dört.to_excel("2014.xlsx",sheet_name="2014")

# %% [markdown]
# # html dosyaları

# %%
b=pd.read_html("https://ipfs.io/ipfs/QmXoypizjW3WknFiJnKLwHCnL72vedxjQkDDP1mXWo6uco/wiki/List_of_banks_in_Turkey.html")

# %%
b[0]
# Out:
#                                     Bank  Foundation  \
# 0                         Ziraat Bankası        1863
# 1                     Türkiye İş Bankası        1924
# 2                           Garanti Bank        1946
# 3                                 Akbank        1948
# 4                  Yapı ve Kredi Bankası        1944
# 5                           Halk Bankası        1938
# 6                              VakıfBank        1954
# 7                             Finansbank        1987
# 8                   Türk Ekonomi Bankası        1927
# 9                              Denizbank        1997
# 10                             HSBC Bank        1990
# 11                              ING Bank        1984
# 12                         Türk Eximbank        1987
# 13                              Odeabank        2012
# 14                             Şekerbank        1953
# 15                         İller Bankası        1933
# 16        Türkiye Sınai Kalkınma Bankası        1950
# ...
